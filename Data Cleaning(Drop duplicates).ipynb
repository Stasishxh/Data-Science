# %%
import pandas as pd
import numpy as np

# %%
IMDB = pd.read_csv('/Users/krittanailueangsudjaichuen/Downloads/IMDb_movies.csv')

# %%
IMDB
# Out:
#       imdb_title_id                                              title  \
# 0         tt0000574                        The Story of the Kelly Gang
# 1         tt0001892                                     Den sorte drøm
# 2         tt0002101                                          Cleopatra
# 3         tt0002130                                          L'Inferno
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# ...             ...                                                ...
# 81268     tt9903716                                             Jessie
# 81269     tt9905412                                              Ottam
# 81270     tt9905462                                          Pengalila
# 81271     tt9911774                          Padmavyuhathile Abhimanyu
# 81272     tt9914286                                  Sokagin Çocuklari
#
#                                           original_title  year date_published  \
# ...

# %%
IMDB.isnull().sum()
# Out:
# imdb_title_id                0
# title                        0
# original_title               0
# year                         0
# date_published               0
# genre                        0
# duration                     0
# country                     39
# language                   755
# director                    73
# writer                    1493
# production_company        4325
# actors                      66
# description               2430
# avg_vote                     0
# votes                        0
# budget                   58469
# usa_gross_income         66179
# worlwide_gross_income    51381
# metascore                68551
# reviews_from_users        7077
# reviews_from_critics     10987
# dtype: int64

# %%
IMDB.isnull().values.any()
# Out:
# True

# %%
IMDB.isnull().sum().sum()
# Out:
# 271825

# %%
df = IMDB.drop_duplicates()

# %%
imdb = df.dropna(axis=1)
imdb.head(15)
# Out:
#    imdb_title_id                                              title  \
# 0      tt0000574                        The Story of the Kelly Gang
# 1      tt0001892                                     Den sorte drøm
# 2      tt0002101                                          Cleopatra
# 3      tt0002130                                          L'Inferno
# 4      tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# 5      tt0002423                                     Madame DuBarry
# 6      tt0002445                                         Quo Vadis?
# 7      tt0002452                              Independenta Romaniei
# 8      tt0002461                                        Richard III
# 9      tt0002646                                           Atlantis
# 10     tt0002844              Fantômas - À l'ombre de la guillotine
# 11     tt0003014                                      Ingeborg Holm
# 12     tt0003037                               Juve contre Fantômas
# ...

# %%
imdb.isnull().sum()
# Out:
# imdb_title_id     0
# title             0
# original_title    0
# year              0
# date_published    0
# genre             0
# duration          0
# avg_vote          0
# votes             0
# dtype: int64

# %%
imdb.describe().T
# Out:
#             count         mean           std     min     25%     50%     75%  \
# year      81273.0  1993.007210     23.992284  1906.0  1979.0  2002.0  2012.0
# duration  81273.0   100.565981     25.320189    40.0    88.0    96.0   108.0
# avg_vote  81273.0     5.926587      1.243315     1.0     5.2     6.1     6.8
# votes     81273.0  9421.771006  52202.447103    99.0   206.0   495.0  1865.0
#
#                 max
# year         2019.0
# duration     3360.0
# avg_vote       10.0
# votes     2159628.0
