# %%
import pandas as pd
import numpy as np

# %%
IMDB = pd.read_csv('/Users/krittanailueangsudjaichuen/Downloads/IMDb_movies.csv')

# %%
IMDB
# Out:
#       imdb_title_id                                              title  \
# 0         tt0000574                        The Story of the Kelly Gang
# 1         tt0001892                                     Den sorte drøm
# 2         tt0002101                                          Cleopatra
# 3         tt0002130                                          L'Inferno
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# ...             ...                                                ...
# 81268     tt9903716                                             Jessie
# 81269     tt9905412                                              Ottam
# 81270     tt9905462                                          Pengalila
# 81271     tt9911774                          Padmavyuhathile Abhimanyu
# 81272     tt9914286                                  Sokagin Çocuklari
#
#                                           original_title  year date_published  \
# ...

# %%
IMDB.isnull()
# Out:
#        imdb_title_id  title  original_title   year  date_published  genre  \
# 0              False  False           False  False           False  False
# 1              False  False           False  False           False  False
# 2              False  False           False  False           False  False
# 3              False  False           False  False           False  False
# 4              False  False           False  False           False  False
# ...              ...    ...             ...    ...             ...    ...
# 81268          False  False           False  False           False  False
# 81269          False  False           False  False           False  False
# 81270          False  False           False  False           False  False
# 81271          False  False           False  False           False  False
# 81272          False  False           False  False           False  False
#
#        duration  country  language  director  ...  actors  description  \
# ...

# %%
IMDB.isnull().sum()
# Out:
# imdb_title_id                0
# title                        0
# original_title               0
# year                         0
# date_published               0
# genre                        0
# duration                     0
# country                     39
# language                   755
# director                    73
# writer                    1493
# production_company        4325
# actors                      66
# description               2430
# avg_vote                     0
# votes                        0
# budget                   58469
# usa_gross_income         66179
# worlwide_gross_income    51381
# metascore                68551
# reviews_from_users        7077
# reviews_from_critics     10987
# dtype: int64

# %%
IMDB.isnull().values.any()
# Out:
# True

# %%
IMDB.isnull().sum().sum()`
# Out:
# 271825

# %%
print (IMDB['language'].isnull())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 81268    False
# 81269    False
# 81270    False
# 81271    False
# 81272    False
# Name: language, Length: 81273, dtype: bool

# %%
IMDB['language'].describe().T
# Out:
# count       80518
# unique       4251
# top       English
# freq        34519
# Name: language, dtype: object

# %%
IMDB['language'].fillna('English',inplace = True)
IMDB['language'].head(15)
# Out:
# 0     English
# 1     English
# 2     English
# 3     Italian
# 4     English
# 5      German
# 6     Italian
# 7     English
# 8     English
# 9      Danish
# 10     French
# 11    English
# 12     French
# 13     French
# 14     French
# Name: language, dtype: object

# %%
IMDB['language'].drop_duplicates()
# Out:
# 0                                   English
# 3                                   Italian
# 5                                    German
# 9                                    Danish
# 10                                   French
#                         ...
# 80991          English, Hungarian, Japanese
# 81062               Italian, Polish, French
# 81103             Tatar, Ukrainian, Russian
# 81179                      Italian, Bengali
# 81214    Thai, English, Mandarin, Cantonese
# Name: language, Length: 4251, dtype: object

# %%
NRFU = IMDB['reviews_from_users'].median()
IMDB['reviews_from_users'].fillna(NRFU,inplace = True)
IMDB['reviews_from_users']
# Out:
# 0         7.0
# 1         4.0
# 2        24.0
# 3        28.0
# 4        12.0
#          ...
# 81268    21.0
# 81269     9.0
# 81270     9.0
# 81271     9.0
# 81272     9.0
# Name: reviews_from_users, Length: 81273, dtype: float64

# %%
NRFC = IMDB['reviews_from_critics'].median()
IMDB['reviews_from_critics'].fillna(NRFC,inplace = True)
IMDB['reviews_from_critics']
# Out:
# 0         7.0
# 1         2.0
# 2         3.0
# 3        14.0
# 4         5.0
#          ...
# 81268     8.0
# 81269     8.0
# 81270     8.0
# 81271     8.0
# 81272     8.0
# Name: reviews_from_critics, Length: 81273, dtype: float64

# %%
IMDB['country'].drop_duplicates()
# Out:
# 0                                           Australia
# 1                                    Germany, Denmark
# 2                                                 USA
# 3                                               Italy
# 5                                             Germany
#                              ...
# 81130                 France, Algeria, Belgium, Qatar
# 81157                                 China, Mongolia
# 81184               Argentina, Germany, Brazil, Spain
# 81185                             Indonesia, Malaysia
# 81207    Sudan, France, Egypt, Germany, Norway, Qatar
# Name: country, Length: 4633, dtype: object

# %%
IMDB['country'].describe().T
# Out:
# count     81234
# unique     4632
# top         USA
# freq      27490
# Name: country, dtype: object

# %%
IMDB['country'].isnull().sum()
# Out:
# 39

# %%
IMDB['country'].fillna('USA',inplace = True)
IMDB['country'].head(15)
# Out:
# 0            Australia
# 1     Germany, Denmark
# 2                  USA
# 3                Italy
# 4                  USA
# 5              Germany
# 6                Italy
# 7              Romania
# 8          France, USA
# 9              Denmark
# 10              France
# 11              Sweden
# 12              France
# 13             Belgium
# 14              France
# Name: country, dtype: object

# %%
IMDB['director'].fillna('Unknown',inplace = True)
IMDB['director'].head(15)
# Out:
# 0                            Charles Tait
# 1                               Urban Gad
# 2                      Charles L. Gaskill
# 3     Francesco Bertolini, Adolfo Padovan
# 4                           Sidney Olcott
# 5                          Ernst Lubitsch
# 6                         Enrico Guazzoni
# 7                     Aristide Demetriade
# 8            André Calmettes, James Keane
# 9                             August Blom
# 10                        Louis Feuillade
# 11                        Victor Sjöström
# 12                        Louis Feuillade
# 13                          Alfred Machin
# 14                        Louis Feuillade
# Name: director, dtype: object

# %%
IMDB['director'].isnull().sum()
# Out:
# 0

# %%
IMDB['writer'].fillna('Unknown',inplace = True)
IMDB['writer'].head(15)
# Out:
# 0                              Charles Tait
# 1     Urban Gad, Gebhard Schätzler-Perasini
# 2                          Victorien Sardou
# 3                           Dante Alighieri
# 4                             Gene Gauntier
# 5                 Norbert Falk, Hanns Kräly
# 6       Henryk Sienkiewicz, Enrico Guazzoni
# 7          Aristide Demetriade, Petre Liciu
# 8          James Keane, William Shakespeare
# 9             Axel Garde, Gerhart Hauptmann
# 10           Marcel Allain, Louis Feuillade
# 11                                Nils Krok
# 12           Marcel Allain, Louis Feuillade
# 13                            Alfred Machin
# 14           Marcel Allain, Louis Feuillade
# Name: writer, dtype: object

# %%
IMDB['writer'].isnull().sum()
# Out:
# 0

# %%
IMDB['production_company'].fillna('Unknown',inplace = True)
IMDB['production_company'].head(15)
# Out:
# 0                               J. and N. Tait
# 1                                     Fotorama
# 2                Helen Gardner Picture Players
# 3                                  Milano Film
# 4                                Kalem Company
# 5                  Projektions-AG Union (PAGU)
# 6                       Società Italiana Cines
# 7     Societatea Filmului de Arta Leon Popescu
# 8                                Le Film d'Art
# 9                                 Nordisk Film
# 10       Société des Etablissements L. Gaumont
# 11                   Svenska Biografteatern AB
# 12       Société des Etablissements L. Gaumont
# 13                           Belge Cinéma Film
# 14       Société des Etablissements L. Gaumont
# Name: production_company, dtype: object

# %%
IMDB['production_company'].isnull().sum()
# Out:
# 0

# %%
IMDB['actors'].fillna('Unknown',inplace = True)
IMDB['actors'].head(15)
# Out:
# 0     Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1     Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2     Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 3     Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# 4     R. Henderson Bland, Percy Dyer, Gene Gauntier,...
# 5     Pola Negri, Emil Jannings, Harry Liedtke, Edua...
# 6     Amleto Novelli, Gustavo Serena, Carlo Cattaneo...
# 7     Aristide Demetriade, Constanta Demetriade, Con...
# 8     Robert Gemp, Frederick Warde, Albert Gardner, ...
# 9     Olaf Fønss, Ida Orloff, Ebba Thomsen, Carl Lau...
# 10    René Navarre, Edmund Breon, Georges Melchior, ...
# 11    Hilda Borgström, Aron Lindgren, Erik Lindholm,...
# 12    René Navarre, Edmund Breon, Georges Melchior, ...
# 13    Baert, Suzanne Berni, Fernand Crommelynck, Nad...
# 14    René Navarre, Edmund Breon, Georges Melchior, ...
# Name: actors, dtype: object

# %%
IMDB['actors'].isnull().sum()
# Out:
# 0

# %%
IMDB['description'].fillna('Unknown',inplace = True)
IMDB['description'].head(15)
# Out:
# 0     True story of notorious Australian outlaw Ned ...
# 1     Two men of high rank are both wooing the beaut...
# 2     The fabled queen of Egypt's affair with Roman ...
# 3     Loosely adapted from Dante's Divine Comedy and...
# 4     An account of the life of Jesus Christ, based ...
# 5     The story of Madame DuBarry, the mistress of L...
# 6     An epic Italian film "Quo Vadis" influenced ma...
# 7     The movie depicts the Romanian War of Independ...
# 8     Richard of Gloucester uses manipulation and mu...
# 9     After Dr. Friedrich's wife becomes mentally un...
# 10    Inspector Juve is tasked to investigate and ca...
# 11    Single mother is separated from her children d...
# 12    In Part Two of Louis Feuillade's 5 1/2-hour ep...
# 13    An army pilot is on a visit at the home of ano...
# 14    After a body disappears from inside the prison...
# Name: description, dtype: object

# %%
IMDB['description'].isnull().sum()
# Out:
# 0

# %%
del IMDB['usa_gross_income']

# %%
del IMDB['worlwide_gross_income']

# %%
del IMDB['metascore']

# %%
del IMDB['budget']

# %%
IMDB.isnull().sum()
# Out:
# imdb_title_id           0
# title                   0
# original_title          0
# year                    0
# date_published          0
# genre                   0
# duration                0
# country                 0
# language                0
# director                0
# writer                  0
# production_company      0
# actors                  0
# description             0
# avg_vote                0
# votes                   0
# reviews_from_users      0
# reviews_from_critics    0
# dtype: int64

# %%
IMDB
# Out:
#       imdb_title_id                                              title  \
# 0         tt0000574                        The Story of the Kelly Gang
# 1         tt0001892                                     Den sorte drøm
# 2         tt0002101                                          Cleopatra
# 3         tt0002130                                          L'Inferno
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# ...             ...                                                ...
# 81268     tt9903716                                             Jessie
# 81269     tt9905412                                              Ottam
# 81270     tt9905462                                          Pengalila
# 81271     tt9911774                          Padmavyuhathile Abhimanyu
# 81272     tt9914286                                  Sokagin Çocuklari
#
#                                           original_title  year date_published  \
# ...

# %%
IMDB.describe().T
# Out:
#                         count         mean           std     min     25%  \
# year                  81273.0  1993.007210     23.992284  1906.0  1979.0
# duration              81273.0   100.565981     25.320189    40.0    88.0
# avg_vote              81273.0     5.926587      1.243315     1.0     5.2
# votes                 81273.0  9421.771006  52202.447103    99.0   206.0
# reviews_from_users    81273.0    40.726994    153.096881     1.0     4.0
# reviews_from_critics  81273.0    25.290010     55.022677     1.0     4.0
#
#                          50%     75%        max
# year                  2002.0  2012.0     2019.0
# duration                96.0   108.0     3360.0
# avg_vote                 6.1     6.8       10.0
# votes                  495.0  1865.0  2159628.0
# reviews_from_users       9.0    23.0     8302.0
# reviews_from_critics     8.0    20.0      987.0

# %%
`dd
